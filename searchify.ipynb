# %% [markdown]
# ###**Importing required libraries and dependencies**

# %%
import os

# %%
# !apt-get install poppler-utils
# !pip install flask
# !pip install pyngrok
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 1s (248 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# Setting up poppler-utils (0.62.0-2ubuntu2.12) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)
# Collecting pyngrok
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 5.4 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (3.13)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=f383da011de826f363f59f80ebebf50244df7a5c6e7d88f4292e746e04c105ae
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-5.1.0

# %%
cd "/content/drive/MyDrive/IR Project/Search App"
# Out:
# /content/drive/MyDrive/IR Project/Search App

# %% [markdown]
# ###**Cloning haystack from GitHub**

# %%
# !git clone https://github.com/deepset-ai/haystack.git
# Out:
# Cloning into 'haystack'...
# remote: Enumerating objects: 12573, done.
# remote: Counting objects: 100% (1967/1967), done.
# remote: Compressing objects: 100% (840/840), done.
# remote: Total 12573 (delta 1388), reused 1555 (delta 1122), pack-reused 10606
# Receiving objects: 100% (12573/12573), 12.03 MiB | 7.28 MiB/s, done.
# Resolving deltas: 100% (9001/9001), done.
# Checking out files: 100% (1002/1002), done.

# %%
cd haystack
# Out:
# /content/drive/MyDrive/IR Project/Search App/haystack

# %%
pip install --editable .
# Out:
# Obtaining file:///content/drive/MyDrive/IR%20Project/Search%20App/haystack
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (57.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (0.37.0)
# Requirement already satisfied: torch<1.10,>1.5 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.9.0+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (2.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (0.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.0 MB/s
# Collecting mlflow<=1.13.1
#   Downloading mlflow-1.13.1-py3-none-any.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 31 kB/s
# Collecting transformers==4.7.0
#   Downloading transformers-4.7.0-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 35.4 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (0.3.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (5.4.8)
# Collecting fastapi
#   Downloading fastapi-0.70.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 603 kB/s
# Collecting uvicorn
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.1 MB/s
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.1.5)
# Collecting elasticsearch<=7.10,>=7.7
#   Downloading elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
#      |████████████████████████████████| 321 kB 45.6 MB/s
# Collecting elastic-apm
#   Downloading elastic_apm-6.6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (348 kB)
#      |████████████████████████████████| 348 kB 45.4 MB/s
# Collecting tox
#   Downloading tox-3.24.4-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.2 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (3.7.1)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 40.2 MB/s
# Collecting pytesseract==0.3.7
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
# Collecting pillow==8.3.2
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 39.6 MB/s
# Collecting pdf2image==1.14.0
#   Downloading pdf2image-1.14.0-py3-none-any.whl (10 kB)
# Collecting sentence-transformers>=0.4.0
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 7.4 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 35.5 MB/s
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (1.4.25)
# Collecting sqlalchemy_utils
#   Downloading SQLAlchemy_Utils-0.37.9-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.1 MB/s
# Collecting faiss-cpu>=1.6.3
#   Downloading faiss_cpu-1.7.1.post2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 24.7 MB/s
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Collecting httptools
#   Downloading httptools-0.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 47.1 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (3.2.5)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (8.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0rc1) (2.6.3)
# Collecting pymilvus
#   Downloading pymilvus-1.1.2-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.2 MB/s
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp37-cp37m-manylinux2010_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.8 MB/s
# Collecting weaviate-client==2.5.0
#   Downloading weaviate_client-2.5.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.3 MB/s
# Collecting ray==1.5.0
#   Downloading ray-1.5.0-cp37-cp37m-manylinux2014_x86_64.whl (51.5 MB)
#      |████████████████████████████████| 51.5 MB 53 kB/s
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.6-py3-none-any.whl (25 kB)
# Collecting quantulum3
#   Downloading quantulum3-0.7.9-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 20.1 MB/s
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 35.5 MB/s
# Collecting uvloop==0.14
#   Downloading uvloop-0.14.0-cp37-cp37m-manylinux2010_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 38.3 MB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.10-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 34.2 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.11.0)
# Collecting gpustat
#   Downloading gpustat-0.6.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 6.9 MB/s
# Collecting aioredis
#   Downloading aioredis-2.0.0-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 7.1 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.13)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.19.5)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.41.0)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 40.4 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.0.2)
# Collecting opencensus
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 45.0 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (7.1.2)
# Collecting redis>=3.5.0
#   Downloading redis-3.5.3-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 572 kB/s
# Collecting pydantic>=1.8
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 25.1 MB/s
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.17.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (2.6.0)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.3.0)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (2019.12.20)
# Collecting huggingface-hub==0.0.8
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 48.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (21.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 37.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (4.8.1)
# Collecting validators>=0.18.2
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0rc1) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0rc1) (2021.5.30)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.28.1->ray==1.5.0->farm-haystack==1.0.0rc1) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.8.2)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 45.8 MB/s
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.3)
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.4.2)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.1.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 5.7 MB/s
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.4)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 28.6 MB/s
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.3.0)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.3-py3-none-any.whl (17 kB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 50.8 MB/s
# Collecting azure-storage-blob>=12.0.0
#   Downloading azure_storage_blob-12.9.0-py2.py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 48.4 MB/s
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.4 MB/s
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.8 MB/s
# Collecting azure-core<2.0.0,>=1.10.0
#   Downloading azure_core-1.19.0-py2.py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 50.1 MB/s
# Collecting cryptography>=2.1.4
#   Downloading cryptography-35.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 33.4 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.20)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.8.9)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.3.0)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.6 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.0.0rc1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.0.0rc1) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.1.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.10.0+cu111)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.22.2.post1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 35.8 MB/s
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.4.2->farm-haystack==1.0.0rc1) (1.1.2)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators>=0.18.2->weaviate-client==2.5.0->farm-haystack==1.0.0rc1) (4.4.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (21.2.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 46.3 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 43.5 MB/s
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.14.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.8 MB/s
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting starlette==0.16.0
#   Downloading starlette-0.16.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 266 kB/s
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.3.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.0 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray==1.5.0->farm-haystack==1.0.0rc1) (7.352.0)
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.7.0->farm-haystack==1.0.0rc1) (3.6.0)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.26.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (2018.9)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.53.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.7.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.7.0->farm-haystack==1.0.0rc1) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.4.8)
# Collecting grpcio-tools<1.38.0,>=1.22.0
#   Downloading grpcio_tools-1.37.1-cp37-cp37m-manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 22.4 MB/s
# Collecting ujson>=2.0.0
#   Downloading ujson-4.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
#      |████████████████████████████████| 214 kB 43.8 MB/s
# Collecting grpcio>=1.28.1
#   Downloading grpcio-1.37.1-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 35.2 MB/s
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack==1.0.0rc1) (4.2.6)
# Collecting num2words
#   Downloading num2words-0.5.10-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 11.6 MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack==1.0.0rc1) (2.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->quantulum3->farm-haystack==1.0.0rc1) (0.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.7.0->farm-haystack==1.0.0rc1) (1.0.1)
# Collecting rdflib>=4.0
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 41.5 MB/s
# Collecting pluggy>=0.12.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==1.0.0rc1) (0.10.2)
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==1.0.0rc1) (1.10.0)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.8.1-py2.py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 34.8 MB/s
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.0-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.3-py2.py3-none-any.whl (496 kB)
#      |████████████████████████████████| 496 kB 49.0 MB/s
# Collecting backports.entry-points-selectable>=1.0.4
#   Downloading backports.entry_points_selectable-1.1.0-py2.py3-none-any.whl (6.2 kB)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.4 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Building wheels for collected packages: pytesseract, alembic, databricks-cli, sentence-transformers, gpustat, langdetect, python-docx, python-multipart, seqeval, tika
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13954 sha256=5f8eb0be6a549cfb9ffab246b5b48327390f2e54741381a510d9d79d436ed1ce
#   Stored in directory: /root/.cache/pip/wheels/67/71/6c/7a8c5ca2e699752506999ae7baeb692e2b4fc6488c2cddcb22
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158172 sha256=34366a133583f060a3ad7ea6c45a07efaffdb6caaeb29d38757c33abc27d6695
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.1-py3-none-any.whl size=106809 sha256=a2cc171dabdcd903ce9c6ad4ff8770f091a5f0b055bd7a341905bb8dcb1a9a9d
#   Stored in directory: /root/.cache/pip/wheels/9b/52/22/3f33277f2e9f68c154591c86bc2fec87697fdf359dffb5d25e
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=e8d658d98c7c3cdb9beff3bb365dcc2cbb587eb088b5ae0b1c17cd144d157919
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=39932a2e454a2f04b3a0bdcbc5b36ae7c6c59190c69e827dec4691a4dd401209
#   Stored in directory: /root/.cache/pip/wheels/e6/67/af/f1ad15974b8fd95f59a63dbf854483ebe5c7a46a93930798b8
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=4dd04c87a41788f772871b0700505f3562074f3af041cd8c29acf1a6b46aee6c
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=fcb60be7c6da07f6acad807742bc9da1c38a65df8108f0c0b9842bf747d3c2d4
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=9c79e31fc1f51d5c469a700041fcaa677a1aefa11fab3f55756e6992255f1e4e
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=bf07c57ac7e62c12959bbd2ddb3add9edd7d17000ab3bb754f568760d538fba6
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32891 sha256=c0a40f4e7b6b3b63f0ac55e90462b617ba2e55ac5640ce10a57724a20c5a82de
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built pytesseract alembic databricks-cli sentence-transformers gpustat langdetect python-docx python-multipart seqeval tika
# Installing collected packages: multidict, yarl, sniffio, smmap, isodate, async-timeout, websocket-client, tokenizers, sacremoses, python-editor, platformdirs, pillow, opencensus-context, mypy-extensions, msrest, marshmallow, Mako, huggingface-hub, grpcio, gitdb, distlib, cryptography, blessings, backports.entry-points-selectable, azure-core, anyio, aiohttp, virtualenv, validators, ujson, typing-inspect, transformers, starlette, sentencepiece, redis, rdflib, querystring-parser, pydantic, py-spy, prometheus-flask-exporter, pluggy, opencensus, num2words, marshmallow-enum, h11, gunicorn, grpcio-tools, gpustat, gitpython, docker, databricks-cli, colorama, azure-storage-blob, asgiref, alembic, aioredis, aiohttp-cors, weaviate-client, uvloop, uvicorn, tox, tika, sqlalchemy-utils, SPARQLWrapper, seqeval, sentence-transformers, ray, quantulum3, python-multipart, python-docx, pytesseract, pymilvus, psycopg2-binary, pdf2image, mmh3, mlflow, langdetect, httptools, fastapi, faiss-cpu, elasticsearch, elastic-apm, dataclasses-json, farm-haystack
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.41.0
#     Uninstalling grpcio-1.41.0:
#       Successfully uninstalled grpcio-1.41.0
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Running setup.py develop for farm-haystack
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest 3.6.4 requires pluggy<0.8,>=0.5, but you have pluggy 1.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Mako-1.1.5 SPARQLWrapper-1.8.5 aiohttp-3.7.4.post0 aiohttp-cors-0.7.0 aioredis-2.0.0 alembic-1.4.1 anyio-3.3.4 asgiref-3.4.1 async-timeout-3.0.1 azure-core-1.19.0 azure-storage-blob-12.9.0 backports.entry-points-selectable-1.1.0 blessings-1.7 colorama-0.4.4 cryptography-35.0.0 databricks-cli-0.16.1 dataclasses-json-0.5.6 distlib-0.3.3 docker-5.0.3 elastic-apm-6.6.0 elasticsearch-7.10.0 faiss-cpu-1.7.1.post2 farm-haystack-1.0.0rc1 fastapi-0.70.0 gitdb-4.0.7 gitpython-3.1.24 gpustat-0.6.0 grpcio-1.37.1 grpcio-tools-1.37.1 gunicorn-20.1.0 h11-0.12.0 httptools-0.3.0 huggingface-hub-0.0.8 isodate-0.6.0 langdetect-1.0.9 marshmallow-3.14.0 marshmallow-enum-1.5.1 mlflow-1.13.1 mmh3-3.0.0 msrest-0.6.21 multidict-5.2.0 mypy-extensions-0.4.3 num2words-0.5.10 opencensus-0.8.0 opencensus-context-0.1.2 pdf2image-1.14.0 pillow-8.3.2 platformdirs-2.4.0 pluggy-1.0.0 prometheus-flask-exporter-0.18.3 psycopg2-binary-2.9.1 py-spy-0.3.10 pydantic-1.8.2 pymilvus-1.1.2 pytesseract-0.3.7 python-docx-0.8.11 python-editor-1.0.4 python-multipart-0.0.5 quantulum3-0.7.9 querystring-parser-1.2.4 ray-1.5.0 rdflib-6.0.2 redis-3.5.3 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 seqeval-1.2.2 smmap-4.0.0 sniffio-1.2.0 sqlalchemy-utils-0.37.9 starlette-0.16.0 tika-1.24 tokenizers-0.10.3 tox-3.24.4 transformers-4.7.0 typing-inspect-0.7.1 ujson-4.2.0 uvicorn-0.15.0 uvloop-0.14.0 validators-0.18.2 virtualenv-20.8.1 weaviate-client-2.5.0 websocket-client-1.2.1 yarl-1.7.0

# %%
cd "/content/drive/MyDrive/IR Project/Search App"
# Out:
# /content/drive/MyDrive/IR Project/Search App

# %% [markdown]
# ###**Running server.py file**

# %%
# !python server.py
# Out:
# /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)
# pdftotext version 0.62.0
# Copyright 2005-2017 The Poppler Developers - http://poppler.freedesktop.org
# Copyright 1996-2011 Glyph & Cog, LLC
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id 'de6c0dea2824b4ab0d4b8545ba5b58a5' already exists in index 'document'
# Duplicate Documents: Document with id '4d5f1510e51ef2c78358b4fd139cb744' already exists in index 'document'
# Duplicate Documents: Document with id '4d5f1510e51ef2c78358b4fd139cb744' already exists in index 'document'
# Duplicate Documents: Document with id '44b295e9973a2dcbe97f30ac892d8a78' already exists in index 'document'
# Duplicate Documents: Document with id '5678dad94dcf1b4067e0b55f0a402d13' already exists in index 'document'
# Duplicate Documents: Document with id '912294b055ee03c0b2544812733e0f72' already exists in index 'document'
# Duplicate Documents: Document with id '422bb2780f404b5465881bf4f5fb33f7' already exists in index 'document'
# Duplicate Documents: Document with id '3de3ca0237f65942f21ddbbe17d94cc2' already exists in index 'document'
# Duplicate Documents: Document with id '79b6addd7d76f96df6dc548f0d456674' already exists in index 'document'
# Duplicate Documents: Document with id '1e901cfa12f93350a2565e77c705f00b' already exists in index 'document'
# Duplicate Documents: Document with id '5e014fd9d14cba09a78502580af8b473' already exists in index 'document'
# Duplicate Documents: Document with id '788871241b3c206b619ad82e02d531fb' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id '75eccdf4613d0951e1e794dd8d257cd6' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id '99b2cac082f8d501f2ce50fd6ff17141' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '6770d38f94ad7bfa658aa24d07011347' already exists in index 'document'
# Duplicate Documents: Document with id '7b4839b084f914f1399eea8ec39c86ca' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'a01dde0a1a933c9550d51d29d957418' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id 'fffdd77ac759db3c6a3fc93d42a476fd' already exists in index 'document'
# Duplicate Documents: Document with id '59ad88b0e6949d97d6190ed974dd03a4' already exists in index 'document'
# Duplicate Documents: Document with id 'ce920afa248f4881f2e0c8726fe79036' already exists in index 'document'
# Duplicate Documents: Document with id '5e62deac516673f28a92c29c52ca865a' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id '202568b62ffa2964b192733a7f59ee30' already exists in index 'document'
# Duplicate Documents: Document with id '4faa8ad5aca15fa85c85223de128a059' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id 'bebf2c569c763c707036e7b455a04ca7' already exists in index 'document'
# Duplicate Documents: Document with id '99b2cac082f8d501f2ce50fd6ff17141' already exists in index 'document'
# Duplicate Documents: Document with id '95e53397898ca94de31e20b43c59282c' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id '53d02cb62b83a214055edb7d51604c5b' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '5cc3cacdec8d459425e4c07af9f0aa85' already exists in index 'document'
# Duplicate Documents: Document with id 'ff1c74ae225c848b345e553d5e22d33f' already exists in index 'document'
# Duplicate Documents: Document with id '75646b478919c1e53c7c914c28574ef4' already exists in index 'document'
# Duplicate Documents: Document with id '87499ec5e9a9158a7dd76567f541d46e' already exists in index 'document'
# Duplicate Documents: Document with id '7af575749438c86bf4f7e36dec60e1f2' already exists in index 'document'
# Duplicate Documents: Document with id 'a51e8f2030a76bb811eb0989e3eb2600' already exists in index 'document'
# Duplicate Documents: Document with id 'fdca736f01dd45b60bb81bb5a314390a' already exists in index 'document'
# Duplicate Documents: Document with id '724f5ede56ec90a4cfc17ca75935291f' already exists in index 'document'
# Duplicate Documents: Document with id '3e993c9f2cc59c9c5926ec76201fccb1' already exists in index 'document'
# Duplicate Documents: Document with id 'c03077a71d5f6da4ee8986ca53d0445b' already exists in index 'document'
# Duplicate Documents: Document with id 'c677995deb0d6e27b908b1b1b9dc6f16' already exists in index 'document'
# Duplicate Documents: Document with id '1adb3cd420aced13125da938ad140b94' already exists in index 'document'
# Duplicate Documents: Document with id '45e4c39b9d553b2fada63c947db002a4' already exists in index 'document'
# Duplicate Documents: Document with id '53d02cb62b83a214055edb7d51604c5b' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '5cc3cacdec8d459425e4c07af9f0aa85' already exists in index 'document'
# Duplicate Documents: Document with id 'ff1c74ae225c848b345e553d5e22d33f' already exists in index 'document'
# Duplicate Documents: Document with id '75646b478919c1e53c7c914c28574ef4' already exists in index 'document'
# Duplicate Documents: Document with id '87499ec5e9a9158a7dd76567f541d46e' already exists in index 'document'
# Duplicate Documents: Document with id '45e4c39b9d553b2fada63c947db002a4' already exists in index 'document'
# Duplicate Documents: Document with id '45e4c39b9d553b2fada63c947db002a4' already exists in index 'document'
# Duplicate Documents: Document with id '45e4c39b9d553b2fada63c947db002a4' already exists in index 'document'
# Duplicate Documents: Document with id 'e489ab8c1ab7d0266ae2eea85ef3e2f2' already exists in index 'document'
# Duplicate Documents: Document with id '92fd2d80ed0c74e62b45fbe199d8f3a5' already exists in index 'document'
# Duplicate Documents: Document with id '88f341fcb381e7177ba3de061792cf7d' already exists in index 'document'
# Duplicate Documents: Document with id '77a38eb28f083a59771e57106db5b042' already exists in index 'document'
# Duplicate Documents: Document with id '98e57b5126844874e488b4d214e42adc' already exists in index 'document'
# Duplicate Documents: Document with id 'a85565fff61ce176b044cdab43ee4262' already exists in index 'document'
# Duplicate Documents: Document with id 'e2a36f4882b186a3ac649ad589a69a2d' already exists in index 'document'
# Duplicate Documents: Document with id 'c2112c55ac4686f619248fbf36392f15' already exists in index 'document'
# Duplicate Documents: Document with id '12a699d4048750427dc56ff34b1a8caf' already exists in index 'document'
# Duplicate Documents: Document with id '7167b0f5fa14bc1f49f28ce1f906bda3' already exists in index 'document'
# Duplicate Documents: Document with id '8a767a6c4c38a36bce19e3c1dda674ca' already exists in index 'document'
# Duplicate Documents: Document with id 'f95a05dbf2fd7c60cef774a40406e5c2' already exists in index 'document'
# Duplicate Documents: Document with id '40fff6a809e53b873cd45d6cc9620fa5' already exists in index 'document'
# Duplicate Documents: Document with id 'c79c66ba9d1f9410cf1842e5c3713e29' already exists in index 'document'
# Duplicate Documents: Document with id 'c03077a71d5f6da4ee8986ca53d0445b' already exists in index 'document'
# Duplicate Documents: Document with id '45e4c39b9d553b2fada63c947db002a4' already exists in index 'document'
# Duplicate Documents: Document with id 'c677995deb0d6e27b908b1b1b9dc6f16' already exists in index 'document'
# Duplicate Documents: Document with id '46b065efdca1c6c947de3a4589184979' already exists in index 'document'
# Duplicate Documents: Document with id 'caa19d44bed64d0277fb117460c453e' already exists in index 'document'
# Duplicate Documents: Document with id '905c65839ede9b5d2e4b81d29bb55a82' already exists in index 'document'
# Duplicate Documents: Document with id 'fff34318c2ab2ab665dc2f43c2d0e59a' already exists in index 'document'
# Duplicate Documents: Document with id '62cb8da73d9c8971ae5f8ff5bdceac47' already exists in index 'document'
# Duplicate Documents: Document with id '83d3cef2c21c066a184115642b5567c1' already exists in index 'document'
# Duplicate Documents: Document with id '9d555d64f1b8c9d803caa3dcd96b0f9a' already exists in index 'document'
# Duplicate Documents: Document with id '2e220bfbe5f5f06b1f48e9f5e464bcaf' already exists in index 'document'
# Duplicate Documents: Document with id '45e4c39b9d553b2fada63c947db002a4' already exists in index 'document'
# Duplicate Documents: Document with id '212980042ebd464c561057741893f069' already exists in index 'document'
# Duplicate Documents: Document with id '59ad88b0e6949d97d6190ed974dd03a4' already exists in index 'document'
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id 'de6c0dea2824b4ab0d4b8545ba5b58a5' already exists in index 'document'
# Duplicate Documents: Document with id '54217ec817a0fddbdcbcac4d02a3511a' already exists in index 'document'
# Duplicate Documents: Document with id '54217ec817a0fddbdcbcac4d02a3511a' already exists in index 'document'
# Duplicate Documents: Document with id '358a15c365c83badc75a6f2272179640' already exists in index 'document'
# Duplicate Documents: Document with id 'ef175376afa08bc2316d7a96b98f8945' already exists in index 'document'
# Duplicate Documents: Document with id 'b4e56467b43fa02025df5d77e16e0a95' already exists in index 'document'
# Duplicate Documents: Document with id '44b295e9973a2dcbe97f30ac892d8a78' already exists in index 'document'
# Duplicate Documents: Document with id '5ada977527151845fd61691d48faf527' already exists in index 'document'
# Duplicate Documents: Document with id 'b0965099351339246fdf0ed246107d8c' already exists in index 'document'
# Duplicate Documents: Document with id '6efcfcc60774d98dc1328fe6f27561c0' already exists in index 'document'
# Duplicate Documents: Document with id '5678dad94dcf1b4067e0b55f0a402d13' already exists in index 'document'
# Duplicate Documents: Document with id '912294b055ee03c0b2544812733e0f72' already exists in index 'document'
# Duplicate Documents: Document with id 'a01dde0a1a933c9550d51d29d957418' already exists in index 'document'
# Duplicate Documents: Document with id '3de3ca0237f65942f21ddbbe17d94cc2' already exists in index 'document'
# Duplicate Documents: Document with id '422bb2780f404b5465881bf4f5fb33f7' already exists in index 'document'
# Duplicate Documents: Document with id '1e901cfa12f93350a2565e77c705f00b' already exists in index 'document'
# Duplicate Documents: Document with id '61646a0fe50b5b00eb6806263a01f761' already exists in index 'document'
# Duplicate Documents: Document with id '5e014fd9d14cba09a78502580af8b473' already exists in index 'document'
# Duplicate Documents: Document with id '79b6addd7d76f96df6dc548f0d456674' already exists in index 'document'
# Duplicate Documents: Document with id '788871241b3c206b619ad82e02d531fb' already exists in index 'document'
# Duplicate Documents: Document with id '6770d38f94ad7bfa658aa24d07011347' already exists in index 'document'
# Duplicate Documents: Document with id '75eccdf4613d0951e1e794dd8d257cd6' already exists in index 'document'
# Duplicate Documents: Document with id '7b4839b084f914f1399eea8ec39c86ca' already exists in index 'document'
# Duplicate Documents: Document with id '3f24f8fc8b2464cbdbed14ccc5637d8b' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id 'fe1eed766671d2e5c186d24a4fe2071f' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '42670fef85e4978bb0c0faad71636f81' already exists in index 'document'
# Duplicate Documents: Document with id '912294b055ee03c0b2544812733e0f72' already exists in index 'document'
# Duplicate Documents: Document with id '422bb2780f404b5465881bf4f5fb33f7' already exists in index 'document'
# Duplicate Documents: Document with id '3de3ca0237f65942f21ddbbe17d94cc2' already exists in index 'document'
# Duplicate Documents: Document with id '79b6addd7d76f96df6dc548f0d456674' already exists in index 'document'
# Duplicate Documents: Document with id '1e901cfa12f93350a2565e77c705f00b' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id '5e014fd9d14cba09a78502580af8b473' already exists in index 'document'
# Duplicate Documents: Document with id '99b2cac082f8d501f2ce50fd6ff17141' already exists in index 'document'
# Duplicate Documents: Document with id '788871241b3c206b619ad82e02d531fb' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id '75eccdf4613d0951e1e794dd8d257cd6' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id 'edff69763ed0ce2bf1915db323415ae4' already exists in index 'document'
# Duplicate Documents: Document with id 'dae2a0087d2737898971981798194150' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id '3e535e28701bb4d09910c2db4bbcd2f5' already exists in index 'document'
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id '4d5f1510e51ef2c78358b4fd139cb744' already exists in index 'document'
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id 'd2ddd54261a11d2ff6c913e69653a941' already exists in index 'document'
# Duplicate Documents: Document with id 'de6c0dea2824b4ab0d4b8545ba5b58a5' already exists in index 'document'
# Duplicate Documents: Document with id '4d5f1510e51ef2c78358b4fd139cb744' already exists in index 'document'
# Duplicate Documents: Document with id '202568b62ffa2964b192733a7f59ee30' already exists in index 'document'
# Duplicate Documents: Document with id '4faa8ad5aca15fa85c85223de128a059' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id 'bebf2c569c763c707036e7b455a04ca7' already exists in index 'document'
# Duplicate Documents: Document with id '99b2cac082f8d501f2ce50fd6ff17141' already exists in index 'document'
# Duplicate Documents: Document with id '95e53397898ca94de31e20b43c59282c' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id '53d02cb62b83a214055edb7d51604c5b' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '5cc3cacdec8d459425e4c07af9f0aa85' already exists in index 'document'
# Duplicate Documents: Document with id 'ff1c74ae225c848b345e553d5e22d33f' already exists in index 'document'
# Duplicate Documents: Document with id '75646b478919c1e53c7c914c28574ef4' already exists in index 'document'
# Duplicate Documents: Document with id '87499ec5e9a9158a7dd76567f541d46e' already exists in index 'document'
# Duplicate Documents: Document with id '7af575749438c86bf4f7e36dec60e1f2' already exists in index 'document'
# Duplicate Documents: Document with id 'a51e8f2030a76bb811eb0989e3eb2600' already exists in index 'document'
# Duplicate Documents: Document with id 'fdca736f01dd45b60bb81bb5a314390a' already exists in index 'document'
# Duplicate Documents: Document with id '724f5ede56ec90a4cfc17ca75935291f' already exists in index 'document'
# Duplicate Documents: Document with id '3e993c9f2cc59c9c5926ec76201fccb1' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id '6770d38f94ad7bfa658aa24d07011347' already exists in index 'document'
# Duplicate Documents: Document with id '7b4839b084f914f1399eea8ec39c86ca' already exists in index 'document'
# Duplicate Documents: Document with id 'd1719b00209667ee6308b0b71817672e' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '86048433b4cd3a5673661a859f1c99ed' already exists in index 'document'
# Duplicate Documents: Document with id 'efdcd3646e7af3ed1f1e032672e7f875' already exists in index 'document'
# Duplicate Documents: Document with id '2869b6a0953a3cb4b07472d56ab5fb04' already exists in index 'document'
# Duplicate Documents: Document with id '4519386d325e5e470e1c7c5f55c3af9d' already exists in index 'document'
# Duplicate Documents: Document with id '90b4748b921e9782e513d40bb204c33d' already exists in index 'document'
# Duplicate Documents: Document with id 'fa04add94125b918db119aeb435bd9d0' already exists in index 'document'
# Duplicate Documents: Document with id 'b0cdecb246715b94bd8899a2404358c8' already exists in index 'document'
# Duplicate Documents: Document with id '28eb1726b9c33edaabf876b4ffa3397e' already exists in index 'document'
# Duplicate Documents: Document with id 'e6892a1c89d33a1b0510ad9cdec69872' already exists in index 'document'
# Duplicate Documents: Document with id '6c3e8b863128581ba383c6440286aeef' already exists in index 'document'
# Duplicate Documents: Document with id '5d5e07a88b0bb43a99a91b898745c3f3' already exists in index 'document'
# Duplicate Documents: Document with id '98534914f60734a6fd87fcba040bdefe' already exists in index 'document'
# Duplicate Documents: Document with id '87c420c0257991bbf0a44b6ba00d9f8d' already exists in index 'document'
# Duplicate Documents: Document with id '7ad8c3dcf1a097e0153ff7093bd3b204' already exists in index 'document'
# Duplicate Documents: Document with id 'c03077a71d5f6da4ee8986ca53d0445b' already exists in index 'document'
# Duplicate Documents: Document with id '8623bbb289342eef151f14ed5d542f60' already exists in index 'document'
# Duplicate Documents: Document with id '2317cf96f44f92c8332ddcbed4f62d3e' already exists in index 'document'
# Duplicate Documents: Document with id '4f7bc44858b9726542d9a9870322d9c5' already exists in index 'document'
# Duplicate Documents: Document with id '208bb498c7da0d950f31e71770462354' already exists in index 'document'
# Duplicate Documents: Document with id 'fda127b05ad4261c941dad2c654abbf4' already exists in index 'document'
# Duplicate Documents: Document with id '50fcc67485226607f9abc1638a55d8b2' already exists in index 'document'
# Duplicate Documents: Document with id 'c677995deb0d6e27b908b1b1b9dc6f16' already exists in index 'document'
# Duplicate Documents: Document with id 'c8ad53cba3ffdd9a00c4f66dc7adea2e' already exists in index 'document'
# Duplicate Documents: Document with id '1a508917eae31720bc4ac42a2c252acd' already exists in index 'document'
# Duplicate Documents: Document with id '55371d429e8b02a84f80c50551ab4548' already exists in index 'document'
# Duplicate Documents: Document with id '6f031771b6d7fd12d172ae2ea1d294b1' already exists in index 'document'
# Duplicate Documents: Document with id '540f212b05b5e71fcaa98109f62bbb6f' already exists in index 'document'
# Duplicate Documents: Document with id 'acacd9d561de10f0d8676ecb681f4b97' already exists in index 'document'
# Duplicate Documents: Document with id 'f7bb4c684db62f9d9ebb641db8163c3d' already exists in index 'document'
# Duplicate Documents: Document with id '2f515a1984aeffe0dc138e29b8b34c59' already exists in index 'document'
# Duplicate Documents: Document with id 'd9dbcd004fb8f7ddc3728ae62bd179cf' already exists in index 'document'
# Duplicate Documents: Document with id '2e220bfbe5f5f06b1f48e9f5e464bcaf' already exists in index 'document'
# Duplicate Documents: Document with id 'b554c893b8b72c1450930815d157aec4' already exists in index 'document'
# Duplicate Documents: Document with id 'fe5b258a9df9b24c80f8e690f109718a' already exists in index 'document'
# Duplicate Documents: Document with id 'e92170421dce7dd8cca09f2f457a347b' already exists in index 'document'
# Duplicate Documents: Document with id 'c4a5c9be037f4f52d5cbbcf6b0ff7417' already exists in index 'document'
# Duplicate Documents: Document with id 'e0a4b151df0bcd4556677d679c9b22c7' already exists in index 'document'
# Duplicate Documents: Document with id '483827648a672db50f0793a240e92937' already exists in index 'document'
# Duplicate Documents: Document with id '212980042ebd464c561057741893f069' already exists in index 'document'
# Duplicate Documents: Document with id '59ad88b0e6949d97d6190ed974dd03a4' already exists in index 'document'
# Duplicate Documents: Document with id 'cf3bc17457844dba1ec96ecb92d09e71' already exists in index 'document'
# Duplicate Documents: Document with id 'da1ff8c9605bbf87c13fe9ee1265d29b' already exists in index 'document'
# Duplicate Documents: Document with id 'c16fec1d3f7d94e61ac9f4a4797b9020' already exists in index 'document'
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id 'abc9e85ebe968f09f9e4dc80643099f6' already exists in index 'document'
# Duplicate Documents: Document with id 'de6c0dea2824b4ab0d4b8545ba5b58a5' already exists in index 'document'
# Duplicate Documents: Document with id '80de0f3f6e33c179f831ea18d5f8d1a6' already exists in index 'document'
# Duplicate Documents: Document with id '54217ec817a0fddbdcbcac4d02a3511a' already exists in index 'document'
# Duplicate Documents: Document with id '7527dd99a16229619345763dde4058ba' already exists in index 'document'
# Duplicate Documents: Document with id '54217ec817a0fddbdcbcac4d02a3511a' already exists in index 'document'
# Duplicate Documents: Document with id '358a15c365c83badc75a6f2272179640' already exists in index 'document'
# Duplicate Documents: Document with id 'ef175376afa08bc2316d7a96b98f8945' already exists in index 'document'
# Duplicate Documents: Document with id 'b4e56467b43fa02025df5d77e16e0a95' already exists in index 'document'
# Duplicate Documents: Document with id '44b295e9973a2dcbe97f30ac892d8a78' already exists in index 'document'
# Duplicate Documents: Document with id '5ada977527151845fd61691d48faf527' already exists in index 'document'
# Duplicate Documents: Document with id 'b0965099351339246fdf0ed246107d8c' already exists in index 'document'
# Duplicate Documents: Document with id '6a620f0e194f2a0978381f675277b3bd' already exists in index 'document'
# Duplicate Documents: Document with id '6efcfcc60774d98dc1328fe6f27561c0' already exists in index 'document'
# Duplicate Documents: Document with id '7efc727548e4eb3e2ce9afbd74931bbb' already exists in index 'document'
# Duplicate Documents: Document with id 'd1a4649b4fe14a6c6cf34f372e70e46d' already exists in index 'document'
# Duplicate Documents: Document with id 'facccde5056b3316da4691f6a81b671c' already exists in index 'document'
# Duplicate Documents: Document with id 'bd295d87652a595d8504dfee6a8b3fc' already exists in index 'document'
# Duplicate Documents: Document with id '274794fdfc2835920ae152ebb5b7b974' already exists in index 'document'
# Duplicate Documents: Document with id 'e875a776918e8ba7eaf8077f9a4a30fd' already exists in index 'document'
# Duplicate Documents: Document with id '5678dad94dcf1b4067e0b55f0a402d13' already exists in index 'document'
# Duplicate Documents: Document with id '912294b055ee03c0b2544812733e0f72' already exists in index 'document'
# Duplicate Documents: Document with id 'a01dde0a1a933c9550d51d29d957418' already exists in index 'document'
# Duplicate Documents: Document with id '3de3ca0237f65942f21ddbbe17d94cc2' already exists in index 'document'
# Duplicate Documents: Document with id '422bb2780f404b5465881bf4f5fb33f7' already exists in index 'document'
# Duplicate Documents: Document with id '1e901cfa12f93350a2565e77c705f00b' already exists in index 'document'
# Duplicate Documents: Document with id '61646a0fe50b5b00eb6806263a01f761' already exists in index 'document'
# Duplicate Documents: Document with id '5e014fd9d14cba09a78502580af8b473' already exists in index 'document'
# Duplicate Documents: Document with id '79b6addd7d76f96df6dc548f0d456674' already exists in index 'document'
# Duplicate Documents: Document with id '788871241b3c206b619ad82e02d531fb' already exists in index 'document'
# Duplicate Documents: Document with id '6770d38f94ad7bfa658aa24d07011347' already exists in index 'document'
# Duplicate Documents: Document with id '75eccdf4613d0951e1e794dd8d257cd6' already exists in index 'document'
# Duplicate Documents: Document with id '7b4839b084f914f1399eea8ec39c86ca' already exists in index 'document'
# Duplicate Documents: Document with id '3f24f8fc8b2464cbdbed14ccc5637d8b' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id 'fe1eed766671d2e5c186d24a4fe2071f' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '42670fef85e4978bb0c0faad71636f81' already exists in index 'document'
# Duplicate Documents: Document with id '54675c435407b8fbbde5488633867a13' already exists in index 'document'
# Duplicate Documents: Document with id '912294b055ee03c0b2544812733e0f72' already exists in index 'document'
# Duplicate Documents: Document with id '422bb2780f404b5465881bf4f5fb33f7' already exists in index 'document'
# Duplicate Documents: Document with id '3de3ca0237f65942f21ddbbe17d94cc2' already exists in index 'document'
# Duplicate Documents: Document with id '79b6addd7d76f96df6dc548f0d456674' already exists in index 'document'
# Duplicate Documents: Document with id '1e901cfa12f93350a2565e77c705f00b' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id '5e014fd9d14cba09a78502580af8b473' already exists in index 'document'
# Duplicate Documents: Document with id '99b2cac082f8d501f2ce50fd6ff17141' already exists in index 'document'
# Duplicate Documents: Document with id '788871241b3c206b619ad82e02d531fb' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id '75eccdf4613d0951e1e794dd8d257cd6' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id 'f19fdadf2b7a042297933891cf3dfede' already exists in index 'document'
# Duplicate Documents: Document with id '8ca56741e85e2eed7d67d90f225750ce' already exists in index 'document'
# Duplicate Documents: Document with id '7e95293026f2881f28a43ef62ffb947d' already exists in index 'document'
# Duplicate Documents: Document with id '562d884447a26a98320fc8a26ed39656' already exists in index 'document'
# Duplicate Documents: Document with id 'a9038dee050bf23005d4c910878b38df' already exists in index 'document'
# Duplicate Documents: Document with id '5b1d518740b1eaad18de35f0ccd1e813' already exists in index 'document'
# Duplicate Documents: Document with id '52ca90212992f1067e50b788361d34dc' already exists in index 'document'
# Duplicate Documents: Document with id 'cd38cf35bed4796c301d34426caf6676' already exists in index 'document'
# Duplicate Documents: Document with id '11031ff38d192d79299de1b6d4936b96' already exists in index 'document'
# Duplicate Documents: Document with id 'a074e1854b573caf6df61b78714df5ec' already exists in index 'document'
# Duplicate Documents: Document with id 'd8eda45331a782bcc59c91a8321837a' already exists in index 'document'
# Duplicate Documents: Document with id '2eac6197ee2315b25a3d419dc4f91865' already exists in index 'document'
# Duplicate Documents: Document with id 'e2f1bf83a5511f10b8a5b4a363e111fa' already exists in index 'document'
# Duplicate Documents: Document with id 'edff69763ed0ce2bf1915db323415ae4' already exists in index 'document'
# Duplicate Documents: Document with id 'dae2a0087d2737898971981798194150' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id '874b23a6c3dfb0cd28f815d1631e5ec5' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id '7577905540159ad06adc6a4b7c49beb2' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '4e988b374d2d4aec50427fdbca1a325f' already exists in index 'document'
# Duplicate Documents: Document with id '6eeb15abac33d60e03da8fdd37aec6a' already exists in index 'document'
# Duplicate Documents: Document with id '3e535e28701bb4d09910c2db4bbcd2f5' already exists in index 'document'
# Duplicate Documents: Document with id '92c03a2a0c722717fad6618a61187761' already exists in index 'document'
# Duplicate Documents: Document with id '942aeb9bf9f0f63771fbbbfe8a7b7c71' already exists in index 'document'
# Duplicate Documents: Document with id '5967bbc2bb1125dd497692bff289820e' already exists in index 'document'
# Duplicate Documents: Document with id 'f620c5d2486e505fc6c7c399a8c3fd3f' already exists in index 'document'
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id '905ccd70b97c8827fedd9461a3715f73' already exists in index 'document'
# Duplicate Documents: Document with id 'd2ddd54261a11d2ff6c913e69653a941' already exists in index 'document'
# Duplicate Documents: Document with id '6fae40281309057628612df4b9fa7a30' already exists in index 'document'
# Duplicate Documents: Document with id '7f39bd83b12f0e32a1396e576103a078' already exists in index 'document'
# Duplicate Documents: Document with id '9ea53e5c63e096beba7a5469d9540318' already exists in index 'document'
# Duplicate Documents: Document with id '4d5f1510e51ef2c78358b4fd139cb744' already exists in index 'document'
# Duplicate Documents: Document with id '738a2b5016aacdd5ccbeefa6841b3ee6' already exists in index 'document'
# Duplicate Documents: Document with id 'd2e09b19b7b1490b9b17168cfb4b2217' already exists in index 'document'
# Duplicate Documents: Document with id '7d85bac78df9425aa968e1ec3c408741' already exists in index 'document'
# Duplicate Documents: Document with id '6edae02a42b463d32399a95bd2b47d01' already exists in index 'document'
# Duplicate Documents: Document with id '57c0cbb202450537fca3acd0cb1cf3ee' already exists in index 'document'
# Duplicate Documents: Document with id '2c53c417636bca02fdd790a5b1612198' already exists in index 'document'
# Duplicate Documents: Document with id '2e44e9daa2c74bd7689120a21d3e8499' already exists in index 'document'
# Duplicate Documents: Document with id 'd2ddd54261a11d2ff6c913e69653a941' already exists in index 'document'
# Duplicate Documents: Document with id 'de6c0dea2824b4ab0d4b8545ba5b58a5' already exists in index 'document'
# Duplicate Documents: Document with id 'd922b5ddaef74a9d860709565029fb60' already exists in index 'document'
# Duplicate Documents: Document with id '4d5f1510e51ef2c78358b4fd139cb744' already exists in index 'document'
# Duplicate Documents: Document with id '8a93421c5eb9c519d97ef281174ed50a' already exists in index 'document'
# Duplicate Documents: Document with id 'e6614b093445e95b4987ec8eeb1109d7' already exists in index 'document'
# Duplicate Documents: Document with id '202568b62ffa2964b192733a7f59ee30' already exists in index 'document'
# Duplicate Documents: Document with id '4faa8ad5aca15fa85c85223de128a059' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id 'bebf2c569c763c707036e7b455a04ca7' already exists in index 'document'
# Duplicate Documents: Document with id '99b2cac082f8d501f2ce50fd6ff17141' already exists in index 'document'
# Duplicate Documents: Document with id '95e53397898ca94de31e20b43c59282c' already exists in index 'document'
# Duplicate Documents: Document with id '692c086283c68326057a05997f8aeb2a' already exists in index 'document'
# Duplicate Documents: Document with id '53d02cb62b83a214055edb7d51604c5b' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '5cc3cacdec8d459425e4c07af9f0aa85' already exists in index 'document'
# Duplicate Documents: Document with id 'ff1c74ae225c848b345e553d5e22d33f' already exists in index 'document'
# Duplicate Documents: Document with id '75646b478919c1e53c7c914c28574ef4' already exists in index 'document'
# Duplicate Documents: Document with id '87499ec5e9a9158a7dd76567f541d46e' already exists in index 'document'
# Duplicate Documents: Document with id '7af575749438c86bf4f7e36dec60e1f2' already exists in index 'document'
# Duplicate Documents: Document with id 'a51e8f2030a76bb811eb0989e3eb2600' already exists in index 'document'
# Duplicate Documents: Document with id 'fdca736f01dd45b60bb81bb5a314390a' already exists in index 'document'
# Duplicate Documents: Document with id '724f5ede56ec90a4cfc17ca75935291f' already exists in index 'document'
# Duplicate Documents: Document with id '3e993c9f2cc59c9c5926ec76201fccb1' already exists in index 'document'
# Duplicate Documents: Document with id 'cb14b0a648c180dce2a644b2b2c0b61a' already exists in index 'document'
# Duplicate Documents: Document with id 'f4c29ad07e7d8e88f319c1fcc326794e' already exists in index 'document'
# Duplicate Documents: Document with id '5ae640264ea66c778b50be3befc090a7' already exists in index 'document'
# Duplicate Documents: Document with id 'd8fcaab1a5c08bf19aadc30bf439ea1b' already exists in index 'document'
# Duplicate Documents: Document with id '86f0c4c29399b47a3e69ca85395a9e34' already exists in index 'document'
# Duplicate Documents: Document with id '98e7e5f999dbfc9f6ca155b8edc51288' already exists in index 'document'
# Duplicate Documents: Document with id '4958596a9aa52c55b18d7f21333cfcd0' already exists in index 'document'
# Duplicate Documents: Document with id '56d722975332cab11c49adc10bc5a629' already exists in index 'document'
# Duplicate Documents: Document with id 'd6ca2be9798811640b5a48461f8c4577' already exists in index 'document'
# Duplicate Documents: Document with id '2e8e81962d74edb9471a454ad572a73f' already exists in index 'document'
# Duplicate Documents: Document with id '4728b2a402e1433378743a9e6480bb8a' already exists in index 'document'
# Duplicate Documents: Document with id '4c02b82dd3a407f1e2da4989f5d32a79' already exists in index 'document'
# Duplicate Documents: Document with id '5507978f18d7912391d9be4823de5eca' already exists in index 'document'
# Duplicate Documents: Document with id '3f255c9f0e187b53899aa8868643f94e' already exists in index 'document'
# Duplicate Documents: Document with id '59f5e68b02849943ef5d4392a9f6b8f9' already exists in index 'document'
# Duplicate Documents: Document with id '7f6b782754a01f31bdd68e2bc5494701' already exists in index 'document'
# Duplicate Documents: Document with id '16312e1a605f9e8541471f0de9d6f2a0' already exists in index 'document'
# Duplicate Documents: Document with id '47b984b103be4beb6d3f080f9ea9134b' already exists in index 'document'
# Duplicate Documents: Document with id 'bfdcfb36f44cb2b5170cda315711ce8' already exists in index 'document'
# Duplicate Documents: Document with id '2b9760c2fb3c05260300e7c470405cb2' already exists in index 'document'
# Duplicate Documents: Document with id '4e9b2479b2f8f6f8b1c5802d487d1326' already exists in index 'document'
# Duplicate Documents: Document with id '6770d38f94ad7bfa658aa24d07011347' already exists in index 'document'
# Duplicate Documents: Document with id '9a6c02b16427c6e77cf3b15fce0ba52' already exists in index 'document'
# Duplicate Documents: Document with id '7b4839b084f914f1399eea8ec39c86ca' already exists in index 'document'
# Duplicate Documents: Document with id 'c7c4aef62c4ebaddd6650a9dc13fad48' already exists in index 'document'
# Duplicate Documents: Document with id 'd1719b00209667ee6308b0b71817672e' already exists in index 'document'
# Duplicate Documents: Document with id '497cc087c05ea8ea6a1b9e2861797210' already exists in index 'document'
# Duplicate Documents: Document with id 'd2fe5d43cec0720d4b6b5cb20f383a6' already exists in index 'document'
# Duplicate Documents: Document with id '74abe3ee910dd89117cdedaf2b1062d5' already exists in index 'document'
# Duplicate Documents: Document with id 'a64d63591bb1607b37c003efaab9af63' already exists in index 'document'
# Duplicate Documents: Document with id 'b3d17424737a31aeafe71d0a1b290b94' already exists in index 'document'
# Duplicate Documents: Document with id '2d3b1b629c59344bd00b19030d7753ce' already exists in index 'document'
# Duplicate Documents: Document with id '6849c0c626d41959f8425c9006465f2b' already exists in index 'document'
# Duplicate Documents: Document with id '86048433b4cd3a5673661a859f1c99ed' already exists in index 'document'
# Duplicate Documents: Document with id '22e7a1ea2a81dbb36491f4de88eefa6a' already exists in index 'document'
# Duplicate Documents: Document with id 'efdcd3646e7af3ed1f1e032672e7f875' already exists in index 'document'
# Duplicate Documents: Document with id '67e4267cf06c14ddc201ab0d91cb3a31' already exists in index 'document'
# Duplicate Documents: Document with id '2869b6a0953a3cb4b07472d56ab5fb04' already exists in index 'document'
# Duplicate Documents: Document with id '4519386d325e5e470e1c7c5f55c3af9d' already exists in index 'document'
# Duplicate Documents: Document with id '90b4748b921e9782e513d40bb204c33d' already exists in index 'document'
# Duplicate Documents: Document with id 'fa04add94125b918db119aeb435bd9d0' already exists in index 'document'
# Duplicate Documents: Document with id 'b0cdecb246715b94bd8899a2404358c8' already exists in index 'document'
# Duplicate Documents: Document with id 'e7ea5c386c9e5c79341078ad25eabcde' already exists in index 'document'
# Duplicate Documents: Document with id '28eb1726b9c33edaabf876b4ffa3397e' already exists in index 'document'
# Duplicate Documents: Document with id 'e6892a1c89d33a1b0510ad9cdec69872' already exists in index 'document'
# Duplicate Documents: Document with id '580fccdddae36aeca743d3426e4b8847' already exists in index 'document'
# Duplicate Documents: Document with id '6c3e8b863128581ba383c6440286aeef' already exists in index 'document'
# Duplicate Documents: Document with id '5d5e07a88b0bb43a99a91b898745c3f3' already exists in index 'document'
# Duplicate Documents: Document with id 'b09cc28c1dd3087be9d5dd710e9f3f58' already exists in index 'document'
# Duplicate Documents: Document with id '98534914f60734a6fd87fcba040bdefe' already exists in index 'document'
# Duplicate Documents: Document with id '87c420c0257991bbf0a44b6ba00d9f8d' already exists in index 'document'
# Duplicate Documents: Document with id 'a6066b0d4d2c07ce2c73e4a60a8149f0' already exists in index 'document'
# Duplicate Documents: Document with id '7ad8c3dcf1a097e0153ff7093bd3b204' already exists in index 'document'
# Duplicate Documents: Document with id 'a9139f51d6656cccacb7e4eb524c64e2' already exists in index 'document'
# Duplicate Documents: Document with id 'c03077a71d5f6da4ee8986ca53d0445b' already exists in index 'document'
# Duplicate Documents: Document with id '8623bbb289342eef151f14ed5d542f60' already exists in index 'document'
# Duplicate Documents: Document with id 'ffbe389e5dc467b03443cc0571d206e2' already exists in index 'document'
# ...
# Duplicate Documents: Document with id 'b09cc28c1dd3087be9d5dd710e9f3f58' already exists in index 'document'
# Duplicate Documents: Document with id '98534914f60734a6fd87fcba040bdefe' already exists in index 'document'
# Duplicate Documents: Document with id '87c420c0257991bbf0a44b6ba00d9f8d' already exists in index 'document'
# Duplicate Documents: Document with id 'a6066b0d4d2c07ce2c73e4a60a8149f0' already exists in index 'document'
# Duplicate Documents: Document with id '7ad8c3dcf1a097e0153ff7093bd3b204' already exists in index 'document'
# Duplicate Documents: Document with id '1dcec28a6ff8393780f5734107b25260' already exists in index 'document'
# Duplicate Documents: Document with id 'a9139f51d6656cccacb7e4eb524c64e2' already exists in index 'document'
# Duplicate Documents: Document with id 'c03077a71d5f6da4ee8986ca53d0445b' already exists in index 'document'
# Duplicate Documents: Document with id '8623bbb289342eef151f14ed5d542f60' already exists in index 'document'
# Duplicate Documents: Document with id 'ffbe389e5dc467b03443cc0571d206e2' already exists in index 'document'
# Duplicate Documents: Document with id '2317cf96f44f92c8332ddcbed4f62d3e' already exists in index 'document'
# Duplicate Documents: Document with id '4f7bc44858b9726542d9a9870322d9c5' already exists in index 'document'
# Duplicate Documents: Document with id '2f7ae4cfa28eb673d722782147b82e31' already exists in index 'document'
# Duplicate Documents: Document with id '208bb498c7da0d950f31e71770462354' already exists in index 'document'
# Duplicate Documents: Document with id 'fda127b05ad4261c941dad2c654abbf4' already exists in index 'document'
# Duplicate Documents: Document with id '50fcc67485226607f9abc1638a55d8b2' already exists in index 'document'
# Duplicate Documents: Document with id 'c677995deb0d6e27b908b1b1b9dc6f16' already exists in index 'document'
# Duplicate Documents: Document with id 'c8ad53cba3ffdd9a00c4f66dc7adea2e' already exists in index 'document'
# Duplicate Documents: Document with id '1516a01302f4f7dab5f488b4e0c03eb7' already exists in index 'document'
# Duplicate Documents: Document with id '1a508917eae31720bc4ac42a2c252acd' already exists in index 'document'
# Duplicate Documents: Document with id '55371d429e8b02a84f80c50551ab4548' already exists in index 'document'
# Duplicate Documents: Document with id 'a9bb4f7e6217eee71b8a1ffc2c2c871b' already exists in index 'document'
# Duplicate Documents: Document with id '6f031771b6d7fd12d172ae2ea1d294b1' already exists in index 'document'
# Duplicate Documents: Document with id '80e2217c677ade7f30cbff5d2ea64a3' already exists in index 'document'
# Duplicate Documents: Document with id '540f212b05b5e71fcaa98109f62bbb6f' already exists in index 'document'
# Duplicate Documents: Document with id 'acacd9d561de10f0d8676ecb681f4b97' already exists in index 'document'
# Duplicate Documents: Document with id 'fba0524e5f7a235b1e874cdf9fbc22da' already exists in index 'document'
# Duplicate Documents: Document with id 'f7bb4c684db62f9d9ebb641db8163c3d' already exists in index 'document'
# Duplicate Documents: Document with id '2f515a1984aeffe0dc138e29b8b34c59' already exists in index 'document'
# Duplicate Documents: Document with id 'd9dbcd004fb8f7ddc3728ae62bd179cf' already exists in index 'document'
# Duplicate Documents: Document with id '2e220bfbe5f5f06b1f48e9f5e464bcaf' already exists in index 'document'
# Duplicate Documents: Document with id 'b554c893b8b72c1450930815d157aec4' already exists in index 'document'
# Duplicate Documents: Document with id '8f9bc9ce5186146a56298c769dae0096' already exists in index 'document'
# Duplicate Documents: Document with id 'fe5b258a9df9b24c80f8e690f109718a' already exists in index 'document'
# Duplicate Documents: Document with id 'e92170421dce7dd8cca09f2f457a347b' already exists in index 'document'
# Duplicate Documents: Document with id 'c4a5c9be037f4f52d5cbbcf6b0ff7417' already exists in index 'document'
# Duplicate Documents: Document with id 'e0a4b151df0bcd4556677d679c9b22c7' already exists in index 'document'
# Duplicate Documents: Document with id '483827648a672db50f0793a240e92937' already exists in index 'document'
# Downloading: 100% 571/571 [00:00<00:00, 180kB/s]
# Downloading: 100% 496M/496M [00:14<00:00, 34.8MB/s]
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaModel: ['qa_outputs.bias', 'qa_outputs.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading: 100% 899k/899k [00:00<00:00, 5.95MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 3.13MB/s]
# Downloading: 100% 772/772 [00:00<00:00, 765kB/s]
# Downloading: 100% 79.0/79.0 [00:00<00:00, 72.3kB/s]
# ML Logging is turned off. No parameters, metrics or artifacts will be logged to MLFlow.
#  * ngrok tunnel "http://e573-34-69-188-223.ngrok.io" -> "http://127.0.0.1:5000/"
#  * Serving Flask app "server" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Oct/2021 06:35:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 06:35:05] "GET /static/js/app.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 06:35:05] "GET /static/js/particles.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 06:35:05] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 06:35:06] "GET /favicon.ico HTTP/1.1" 404 -
# What is Sunset Clause?
# In predict function
# What is Sunset Clause?
# Inferencing Samples:   0% 0/1 [00:00<?, ? Batches/s]/usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Inferencing Samples: 100% 1/1 [00:00<00:00,  2.43 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 14.97 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 16.61 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 17.17 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 17.27 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 18.68 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 12.88 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 13.42 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 14.13 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 20.27 Batches/s]
# [   {   'answer': 'If at the renewal falling due any time between 1st July '
#                   '2002 and 30th June 2003, both\n'
#                   'days inclusive, (after completion of the full policy period '
#                   'of 12 months) an insured becomes entitled to an\n'
#                   'NCB of 55% or 65% in terms of the Tariff prevailing prior '
#                   'to 1st July 2002',
#         'context': 'If at the renewal falling due any time between 1st July '
#                    '2002 and 30th June 2003, both\n'
#                    'days inclusive, (after completion of the full policy '
#                    'period of 12 months) an insured becomes entitled to an\n'
#                    'NCB of 55% or 65% in terms of the Tariff prevailing prior '
#                    'to 1st July 2002'},
#     {   'answer': 'If at the renewal falling due any time between 1st July '
#                   '2002 and 30th June 2003, both\n'
#                   'days inclusive, (after completion of the full policy period '
#                   'of 12 months',
#         'context': 'If at the renewal falling due any time between 1st July '
#                    '2002 and 30th June 2003, both\n'
#                    'days inclusive, (after completion of the full policy '
#                    'period of 12 months'},
#     {   'answer': 'If at the renewal falling due any time between 1st July '
#                   '2002 and 30th June 2003, both\n'
#                   'days inclusive, (after completion of the full policy period '
#                   'of 12 months',
#         'context': 'If at the renewal falling due any time between 1st July '
#                    '2002 and 30th June 2003, both\n'
#                    'days inclusive, (after completion of the full policy '
#                    'period of 12 months'},
#     {   'answer': 'If at the renewal falling due any time between 1st July '
#                   '2002 and 30th June 2003',
#         'context': 'ation\n'
#                    'of the Policy.\n'
#                    'Sunset Clause: If at the renewal falling due any time '
#                    'between 1st July 2002 and 30th June 2003, both days '
#                    'inclusive,\n'
#                    '(after compl'},
#     {   'answer': 'If at the renewal falling due any time between 1st July '
#                   '2002 and 30th June 2003, both\n'
#                   'days inclusive, (after completion of the full policy period '
#                   'of 12 months) an insured becomes entitled to an\n'
#                   'NCB of 55% or 65%',
#         'context': ' If at the renewal falling due any time between 1st July '
#                    '2002 and 30th June 2003, both\n'
#                    'days inclusive, (after completion of the full policy '
#                    'period of 12 months) an insured becomes entitled to an\n'
#                    'NCB of 55% or 65%'}]
# prediction time: 1.58s
# {'query': 'What is Sunset Clause?', 'no_ans_gap': 5.069076299667358, 'answers': [Answer(answer='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months) an insured becomes entitled to an\nNCB of 55% or 65% in terms of the Tariff prevailing prior to 1st July 2002', type='extractive', score=0.4772675260901451, context='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months) an insured becomes entitled to an\nNCB of 55% or 65% in terms of the Tariff prevailing prior to 1st July 2002', offsets_in_document=[Span(start=61, end=329)], offsets_in_context=[Span(start=0, end=268)], document_id='a5d11e34054afa418e94229c749e9cfe', meta={'name': 'Digit Private Car (Bundled) – Add-Ons.pdf'}), Answer(answer='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months', type='extractive', score=0.4138060510158539, context='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months', offsets_in_document=[Span(start=659, end=817)], offsets_in_context=[Span(start=0, end=158)], document_id='bc25751d06c68ec8f940a390b5d37f79', meta={'name': 'Digit Private Car Policy.pdf'}), Answer(answer='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months', type='extractive', score=0.4135681092739105, context='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months', offsets_in_document=[Span(start=642, end=800)], offsets_in_context=[Span(start=0, end=158)], document_id='f823f2bb88c3ae9e83e211a2cd7b82e6', meta={'name': 'Digit Private Car Add-On Covers.pdf'}), Answer(answer='If at the renewal falling due any time between 1st July 2002 and 30th June 2003', type='extractive', score=0.368515320122242, context='ation\nof the Policy.\nSunset Clause: If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both days inclusive,\n(after compl', offsets_in_document=[Span(start=517, end=596)], offsets_in_context=[Span(start=36, end=115)], document_id='16627a967568d55b70e2a4f65f82cbe1', meta={'name': 'Digit Private Car Policy (Optional Add-ons).pdf'}), Answer(answer='If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months) an insured becomes entitled to an\nNCB of 55% or 65%', type='extractive', score=0.35600633919239044, context=' If at the renewal falling due any time between 1st July 2002 and 30th June 2003, both\ndays inclusive, (after completion of the full policy period of 12 months) an insured becomes entitled to an\nNCB of 55% or 65%', offsets_in_document=[Span(start=642, end=853)], offsets_in_context=[Span(start=1, end=212)], document_id='b965fb3f937687ec4d3e9eff57eb28c2', meta={'name': 'Private Car Stand Alone Own Damage Add -On Cover.pdf'})], 'documents': [{'content': "What's Covered:\nSECTION I: Loss of or Damage to the Vehicle Insured", 'content_type': 'text', 'score': None, 'meta': {'name': 'Digit Commercial Vehicle - Misc. and Special Type of Vehicles.pdf'}, 'embedding': None, 'id': 'c16fec1d3f7d94e61ac9f4a4797b9020'}, {'content': "Any accidental loss damage and/or liability caused sustained or incurred whilst the vehicle\ninsured herein is\na. being used otherwise than in accordance with the `Limitations as to Use' or\nb. being driven by or is for the purpose of being driven by him/her in the charge of any person\nother than a Driver as stated in the Driver's Clause.", 'content_type': 'text', 'score': None, 'meta': {'name':  ...
# 127.0.0.1 - - [21/Oct/2021 06:45:11] "POST /search HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 06:45:12] "GET /static/css/style_search.css HTTP/1.1" 200 -
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/genericpath.py", line 19, in exists
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#     os.stat(path)
# KeyboardInterrupt

# %%
# !python server2.py
# Out:
# /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)
# pdftotext version 0.62.0
# Copyright 2005-2017 The Poppler Developers - http://poppler.freedesktop.org
# Copyright 1996-2011 Glyph & Cog, LLC
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Syntax Warning: Invalid Font Weight
# Updating Embedding:   0% 0/816 [00:00<?, ? docs/s]
# Create embeddings:   0% 0/816 [00:00<?, ? Docs/s]
# Create embeddings:   2% 16/816 [00:00<00:28, 28.30 Docs/s]
# Create embeddings:   4% 32/816 [00:01<00:25, 30.83 Docs/s]
# Create embeddings:   6% 48/816 [00:01<00:24, 31.44 Docs/s]
# Create embeddings:   8% 64/816 [00:02<00:23, 31.74 Docs/s]
# Create embeddings:  10% 80/816 [00:02<00:23, 31.92 Docs/s]
# Create embeddings:  12% 96/816 [00:03<00:22, 32.10 Docs/s]
# Create embeddings:  14% 112/816 [00:03<00:21, 32.15 Docs/s]
# Create embeddings:  16% 128/816 [00:04<00:21, 32.22 Docs/s]
# Create embeddings:  18% 144/816 [00:04<00:20, 32.27 Docs/s]
# Create embeddings:  20% 160/816 [00:05<00:20, 32.29 Docs/s]
# Create embeddings:  22% 176/816 [00:05<00:19, 32.27 Docs/s]
# Create embeddings:  24% 192/816 [00:06<00:19, 32.25 Docs/s]
# Create embeddings:  25% 208/816 [00:06<00:18, 32.23 Docs/s]
# Create embeddings:  27% 224/816 [00:06<00:18, 32.25 Docs/s]
# Create embeddings:  29% 240/816 [00:07<00:17, 32.29 Docs/s]
# Create embeddings:  31% 256/816 [00:07<00:17, 32.29 Docs/s]
# Create embeddings:  33% 272/816 [00:08<00:16, 32.27 Docs/s]
# Create embeddings:  35% 288/816 [00:08<00:16, 32.25 Docs/s]
# Create embeddings:  37% 304/816 [00:09<00:15, 32.23 Docs/s]
# Create embeddings:  39% 320/816 [00:09<00:15, 32.22 Docs/s]
# Create embeddings:  41% 336/816 [00:10<00:14, 32.21 Docs/s]
# Create embeddings:  43% 352/816 [00:10<00:14, 32.20 Docs/s]
# Create embeddings:  45% 368/816 [00:11<00:13, 32.19 Docs/s]
# Create embeddings:  47% 384/816 [00:11<00:13, 32.21 Docs/s]
# Create embeddings:  49% 400/816 [00:12<00:12, 32.19 Docs/s]
# Create embeddings:  51% 416/816 [00:12<00:12, 32.20 Docs/s]
# Create embeddings:  53% 432/816 [00:13<00:11, 32.21 Docs/s]
# Create embeddings:  55% 448/816 [00:13<00:11, 32.19 Docs/s]
# Create embeddings:  57% 464/816 [00:14<00:10, 32.20 Docs/s]
# Create embeddings:  59% 480/816 [00:14<00:10, 32.21 Docs/s]
# Create embeddings:  61% 496/816 [00:15<00:09, 32.22 Docs/s]
# Create embeddings:  63% 512/816 [00:15<00:09, 32.25 Docs/s]
# Create embeddings:  65% 528/816 [00:16<00:08, 32.23 Docs/s]
# Create embeddings:  67% 544/816 [00:16<00:08, 32.20 Docs/s]
# Create embeddings:  69% 560/816 [00:17<00:07, 32.21 Docs/s]
# Create embeddings:  71% 576/816 [00:17<00:07, 32.20 Docs/s]
# Create embeddings:  73% 592/816 [00:18<00:06, 32.21 Docs/s]
# Create embeddings:  75% 608/816 [00:18<00:06, 32.21 Docs/s]
# Create embeddings:  76% 624/816 [00:19<00:05, 32.23 Docs/s]
# Create embeddings:  78% 640/816 [00:19<00:05, 32.20 Docs/s]
# Create embeddings:  80% 656/816 [00:20<00:04, 32.21 Docs/s]
# Create embeddings:  82% 672/816 [00:20<00:04, 32.20 Docs/s]
# Create embeddings:  84% 688/816 [00:21<00:03, 32.20 Docs/s]
# Create embeddings:  86% 704/816 [00:21<00:03, 32.21 Docs/s]
# Create embeddings:  88% 720/816 [00:22<00:02, 32.20 Docs/s]
# Create embeddings:  90% 736/816 [00:22<00:02, 32.20 Docs/s]
# Create embeddings:  92% 752/816 [00:23<00:01, 32.20 Docs/s]
# Create embeddings:  94% 768/816 [00:23<00:01, 32.20 Docs/s]
# Create embeddings:  96% 784/816 [00:24<00:00, 32.17 Docs/s]
# Create embeddings:  98% 800/816 [00:24<00:00, 32.18 Docs/s]
# Create embeddings: 100% 816/816 [00:25<00:00, 32.18 Docs/s]
# Documents Processed: 10000 docs [00:26, 381.74 docs/s]
# Some weights of the model checkpoint at deepset/roberta-base-squad2 were not used when initializing RobertaModel: ['qa_outputs.bias', 'qa_outputs.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Failed to log params: Changing param values is not allowed. Param with key='prediction_heads' was already logged with value='TextSimilarityHead' for run ID='76d30385b44c4e09b747841b0cda48aa'. Attempted logging new value 'QuestionAnsweringHead'.
# Failed to log params: Changing param values is not allowed. Param with key='processor' was already logged with value='TextSimilarityProcessor' for run ID='76d30385b44c4e09b747841b0cda48aa'. Attempted logging new value 'SquadProcessor'.
# ML Logging is turned off. No parameters, metrics or artifacts will be logged to MLFlow.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#  * ngrok tunnel "http://9cb2-34-69-188-223.ngrok.io" -> "http://127.0.0.1:5001/"
#  * Serving Flask app "server2" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5001/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Oct/2021 07:11:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 07:11:58] "GET /static/js/app.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 07:11:58] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 07:11:58] "GET /static/js/particles.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 07:11:59] "GET /favicon.ico HTTP/1.1" 404 -
# Ahmedabad Office Details
# In predict function
# Ahmedabad Office Details
# Inferencing Samples:   0% 0/1 [00:00<?, ? Batches/s]/usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Inferencing Samples: 100% 1/1 [00:00<00:00,  5.56 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00,  4.77 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00,  7.93 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 13.98 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 15.47 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 15.42 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 15.29 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 17.24 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 17.24 Batches/s]
# Inferencing Samples: 100% 1/1 [00:00<00:00, 17.67 Batches/s]
# [   {   'answer': 'Office of the Insurance Ombudsman',
#         'context': 'Office of the Insurance Ombudsman, Jeevan Prakash '
#                    'Building, 6th\n'
#                    'floor, Tilak Marg, Relief Road, Ahmedabad  380 001. Tel.: '
#                    '07925501201/02/05/06\n'
#                    'Email: '},
#     {   'answer': 'Office of the Insurance Ombudsman',
#         'context': 'Office of the Insurance Ombudsman, Jeevan Prakash '
#                    'Building, 6th\n'
#                    'floor, Tilak Marg, Relief Road, Ahmedabad  380 001. Tel.: '
#                    '07925501201 / 02 / 05 / 06\n'
#                    'E'},
#     {   'answer': 'bimalokpal',
#         'context': 'Tel.: 079 - 25501201/02/05/06,\n'
#                    'Email: bimalokpal.ahmedabad@ecoi.co.in'},
#     {'answer': 'AHMEDABAD', 'context': 'Office Location\nAHMEDABAD'},
#     {   'answer': 'AHMEDABAD',
#         'context': 'Back to Index | 13\n\x0cOffice Location\nAHMEDABAD'}]
# prediction time: 1.42s
# {'query': 'Ahmedabad Office Details', 'no_ans_gap': -1.531257688999176, 'answers': [Answer(answer='Office of the Insurance Ombudsman', type='extractive', score=0.20077186077833176, context='Office of the Insurance Ombudsman, Jeevan Prakash Building, 6th\nfloor, Tilak Marg, Relief Road, Ahmedabad  380 001. Tel.: 07925501201/02/05/06\nEmail: ', offsets_in_document=[Span(start=0, end=33)], offsets_in_context=[Span(start=0, end=33)], document_id='67e4267cf06c14ddc201ab0d91cb3a31', meta={'name': 'Private Private Car Policy,Digit Private Car Policy.pdf', 'vector_id': '450'}), Answer(answer='Office of the Insurance Ombudsman', type='extractive', score=0.17104212939739227, context='Office of the Insurance Ombudsman, Jeevan Prakash Building, 6th\nfloor, Tilak Marg, Relief Road, Ahmedabad  380 001. Tel.: 07925501201 / 02 / 05 / 06\nE', offsets_in_document=[Span(start=0, end=33)], offsets_in_context=[Span(start=0, end=33)], document_id='c4be120a8fa719a1c5bc12214f05fcdb', meta={'name': 'Commercial Vehicle Liability Only Policy Wordings - Digit Insurance.pdf', 'vector_id': '265'}), Answer(answer='bimalokpal', type='extractive', score=0.05278639867901802, context='Tel.: 079 - 25501201/02/05/06,\nEmail: bimalokpal.ahmedabad@ecoi.co.in', offsets_in_document=[Span(start=38, end=48)], offsets_in_context=[Span(start=38, end=48)], document_id='8146db9a83cbddeb14ac3846ef25c715', meta={'name': 'Private Car Liability Only Policy.pdf', 'vector_id': '102'}), Answer(answer='AHMEDABAD', type='extractive', score=0.038948945701122284, context='Office Location\nAHMEDABAD', offsets_in_document=[Span(start=16, end=25)], offsets_in_context=[Span(start=16, end=25)], document_id='1755c46daccf1ff023c02bc4570bab41', meta={'name': 'Private Car Liability Only Policy.pdf', 'vector_id': '799'}), Answer(answer='AHMEDABAD', type='extractive', score=0.03218083409592509, context='Back to Index | 13\n\x0cOffice Location\nAHMEDABAD', offsets_in_document=[Span(start=36, end=45)], offsets_in_context=[Span(start=36, end=45)], document_id='b7a59a63a285470c224a685d306cdf0f', meta={'name': 'Digit Private Car Policy.pdf', 'vector_id': '99'})], 'documents': [{'content': 'Office Location\nAHMEDABAD', 'content_type': 'text', 'score': 0.6721744606935163, 'meta': {'name': 'Private Car Liability Only Policy.pdf', 'vector_id': '799'}, 'embedding': None, 'id': '1755c46daccf1ff023c02bc4570bab41'}, {'content': 'Back to Index | 13\n\x0cOffice Location\nAHMEDABAD', 'content_type': 'text', 'score': 0.6717155857426361, 'meta': {'name': 'Digit Private Car Policy.pdf', 'vector_id': '99'}, 'embedding': None, 'id': 'b7a59a63a285470c224a685d306cdf0f'}, {'content': 'Ahmedabad', 'content_type': 'text', 'score': 0.6677771257799427, 'meta': {'name': 'Private Private Car Policy,Digit Private Car Policy.pdf', 'vector_id': '264'}, 'embedding': None, 'id': 'efdcd3646e7af3ed1f1e032672e7f875'}, {'content': 'AHMEDABAD', 'content_type': 'text', 'score': 0.66728202807737, 'meta': {'name': 'Policy Wording Private Car Liability Only Policy - Long Term (3 Years).pdf', 'vector_id': '340'}, 'embedding': None, 'id': '169048e4355d749b0bc342fa173a4cf0'}, {'content': 'Office of the Insurance Ombudsman, Jeevan Prakash Building, 6th\nfloor, Tilak Marg, Relief Road, Ahmedabad  380 001. Tel.: 07925501201/02/05/06\nEmail: bimalokpal.ahmedabad@gbic.co.in', 'content_type': 'text', 'score': 0.6649736042268384, 'meta': {'name': 'Private Private Car Policy,Digit Private Car Policy.pdf', 'vector_id': '450'}, 'embedding': None, 'id': '67e4267cf06c14ddc201ab0d91cb3a31'}, {'content': 'Office of the Insurance Ombudsman, Jeevan Prakash Building, 6th\nfloor, Tilak Marg, Relief Road, Ahmedabad  380 001. Tel.: 07925501201 / 02 / 05 / 06\nEmail: bimalokpal.ahmedabad@gbic.co.in', 'content_type': 'text', 'score': 0.6610647779880032, 'meta': {'name': 'Commercial Vehicle Liability Only Policy Wordings - Digit Insurance.pdf', 'vector_id': '265'}, 'embedding': None, 'id': 'c4be120a8fa719a1c5bc12214f05fcdb'}, {'content': 'Tel.: 079 - 25501201/02/ ...
# 127.0.0.1 - - [21/Oct/2021 07:12:05] "POST /search HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2021 07:12:05] "GET /static/css/style_search.css HTTP/1.1" 200 -
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
